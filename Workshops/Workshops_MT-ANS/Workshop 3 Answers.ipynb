# %% [markdown]
# # Workshop 3: Data Analysis

# %% [markdown]
# ## Exercise 1: Illegal Imports

# %% [markdown]
# Import all the python packages that will be required through this workshop. Then, create your own pandas dataframe with at least two rows and three columns (I leave the contents up to you)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

First_Names = ['Clark', 'Bruce', 'Diana', 'Iris']
Last_Names = ['Kent', 'Wayne', 'Prince', 'West']
df = pd.DataFrame([First_Names, Last_Names])
df
# Out:
#        0      1       2     3
# 0  Clark  Bruce   Diana  Iris
# 1   Kent  Wayne  Prince  West

# %% [markdown]
# ## Exercise 2: Data Framed

# %% [markdown]
# Sample 10 of your classmates for their favorite movies. Then create a Pandas dataframe where one column lists the classmates and the other lists their associated movie.

# %%
movies = [('Sierra', 'A Silent Voice'), ('Alyssa', 'The Dictator'), 
          ('Trish', 'Harry Potter'), ('Ankita', 'Despicable Me'), ('Arjun', 'Interstellar'), 
          ('Jerry', 'Top Gun'), ('Siyuan', 'Oceans Eleven'), ('Anshul', 'Inception'), 
          ('Aaron', 'The Martian'), ('Daniel', 'Inception')]

df = pd.DataFrame(movies, columns=['Name', 'Favorite Movie']) 
df
# Out:
#      Name  Favorite Movie
# 0  Sierra  A Silent Voice
# 1  Alyssa    The Dictator
# 2   Trish    Harry Potter
# 3  Ankita   Despicable Me
# 4   Arjun    Interstellar
# 5   Jerry         Top Gun
# 6  Siyuan   Oceans Eleven
# 7  Anshul       Inception
# 8   Aaron     The Martian
# 9  Daniel       Inception

# %% [markdown]
# ## Exercise 3: Population Control

# %% [markdown]
# Import the nationData.csv file. Use that data to create a histogram of the population of the different South American nations. What is something about the population of the South American continent that you can learn from this plot?

# %%
nations = pd.read_csv('nationData.csv', header = 1)
df_nations = pd.DataFrame(nations)
df_nations
# Out:
#       Country       Capital  Population (millions)
# 0   Argentina  Buenos Aires                   42.8
# 1     Bolivia         Sucre                   10.1
# 2      Brazil      Brasilia                  203.4
# 3       Chile      Santiago                   16.9
# 4    Colombia        Bogota                   46.4
# 5     Ecuador         Quito                   15.0
# 6      Guyana    Georgetown                    0.7
# 7    Paraguay      Asuncion                    6.5
# 8        Peru          Lima                   29.2
# 9    Suriname    Paramaribo                    0.5
# 10    Uruguay    Montevideo                    3.3
# 11  Venezuela       Caracas                   27.6

# %%
plt.hist(df_nations['Population (millions)'], bins = 100);
plt.xlabel('Population')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_nations.plot.bar()
plt.xlabel('Country')
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %% [markdown]
# ## Exercise 4: Campbell Hall Projectile Test

# %% [markdown]
# Read in the file named "projectile.csv" into a Pandas dataframe. Print out your DataFrame. Then plot the data in a scatterplot of position vs time.

# %%
campbell = pd.read_csv('projectile.csv', index_col=0)
df_campbell = pd.DataFrame(campbell)
print(df_campbell)
df_campbell.plot.scatter('Time [s]', 'Position [m]')
# Out:
#     Time [s]  Position [m]
# 0   0.000000     95.000000
# 1   0.097959     96.128490
# 2   0.195918    102.162939
# 3   0.293878    103.103347
# 4   0.391837    102.949714
# 5   0.489796    102.702041
# 6   0.587755    109.360326
# 7   0.685714    101.924571
# 8   0.783673    106.394775
# 9   0.881633    108.770939
# 10  0.979592    106.053061
# 11  1.077551    107.241143
# 12  1.175510    104.335184
# 13  1.273469    106.335184
# 14  1.371429    107.241143
# 15  1.469388    105.053061
# 16  1.567347    102.770939
# 17  1.665306    102.394775
# 18  1.763265    105.924571
# 19  1.861224    109.360326
# 20  1.959184    102.702041
# 21  2.057143    104.949714
# 22  2.155102    100.103347
# 23  2.253061    106.162939
# 24  2.351020     97.128490
# 25  2.448980    101.000000
# 26  2.546939    101.777469
# 27  2.644898     96.460898
# 28  2.742857    101.050286
# 29  2.840816     98.545633
# 30  2.938776     91.946939
# 31  3.036735     89.254204
# 32  3.134694     91.467429
# 33  3.232653     83.586612
# 34  3.330612     90.611755
# 35  3.428571     80.542857
# 36  3.526531     85.379918
# 37  3.624490     84.122939
# 38  3.722449     79.771918
# 39  3.820408     78.326857
# 40  3.918367     67.787755
# 41  4.016327     68.154612
# 42  4.114286     67.427429
# 43  4.212245     59.606204
# 44  4.310204     64.690939
# 45  4.408163     60.681633
# 46  4.506122     51.578286
# 47  4.604082     55.380898
# 48  4.702041     50.089469
# 49  4.800000     47.704000
# <AxesSubplot:xlabel='Time [s]', ylabel='Position [m]'>

# %% [markdown]
# ## Exercise 5: Stellar Nuclear Energy Generation

# %% [markdown]
# Import the isochrone.csv into a pandas dataframe. This data set lists the stellar properties of stars of different masses (measured relative to the mass of the sun). Plot the central temperature and density for each
# star as a function of initial mass for stars on the main-sequence. What do these plots tell you?

# %%
stellar_data = pd.read_csv('isochrone.csv')
df_star = pd.DataFrame(stellar_data)
plt.figure()
df_star.plot('initial_mass', 'log_center_T')
plt.xlabel('Initial Mass (Solar Masses)')
plt.ylabel('Central Temperature (log(K))')

plt.figure()
df_star.plot('initial_mass', 'log_center_Rho')
plt.xlabel('Initial Mass (Solar Masses)')
plt.ylabel('log(Central Density)')
# Out:
# Text(0, 0.5, 'log(Central Density)')

# %% [markdown]
# ## Exercise 6: Presidential Pandas

# %% [markdown]
# This week you were shown how python and pandas can be used to study and understand the behavior of voters in U.S. elections. Now, you are going to try to do a little of that yourself.
# 1. Use pandas to load in the 1976-2020-presdient.csv file into a dataframe. Pick one state from the dataframe to study (just for my own curiosity also list why you picked your state).
# 1. Create a plot showing the number of votes the Republican candiadate and Democratic candidate recieved in your state each year since 1976 (should be one plot with two lines on it properly labeled so it is easy to read). Your plot should also display the number of third party votes cast in each election (lumping all third parties into one group).
# 1. Finally, create a histogram showing the number of times a certain party's candidate recieved the most votes in your state (again you can lump all the third parties together). What does your analysis tell you about the voting trends in your state?

# %%
president_data = pd.read_csv('1976-2020-president.csv')
df_pres = pd.DataFrame(president_data)
df_pres
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
#                     candidate              party_detailed writein  \
# 0               CARTER, JIMMY                    DEMOCRAT   False
# 1                FORD, GERALD                  REPUBLICAN   False
# 2              MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3     BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                   HALL, GUS         COMMUNIST PARTY USE   False
# ...                       ...                         ...     ...
# 4282            JORGENSEN, JO                 LIBERTARIAN   False
# 4283            PIERCE, BROCK                 INDEPENDENT   False
# 4284                      NaN                         NaN    True
# 4285                OVERVOTES                         NaN   False
# 4286               UNDERVOTES                         NaN   False
#
#       candidatevotes  totalvotes   version  notes party_simplified
# 0             659170     1182850  20210113    NaN         DEMOCRAT
# 1             504070     1182850  20210113    NaN       REPUBLICAN
# 2               9198     1182850  20210113    NaN            OTHER
# 3               6669     1182850  20210113    NaN            OTHER
# 4               1954     1182850  20210113    NaN            OTHER
# ...              ...         ...       ...    ...              ...
# 4282            5768      278503  20210113    NaN      LIBERTARIAN
# 4283            2208      278503  20210113    NaN            OTHER
# 4284            1739      278503  20210113    NaN            OTHER
# 4285             279      278503  20210113    NaN            OTHER
# 4286            1459      278503  20210113    NaN            OTHER
#
# [4287 rows x 15 columns]

# %%
df_pres
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
#                     candidate              party_detailed writein  \
# 0               CARTER, JIMMY                    DEMOCRAT   False
# 1                FORD, GERALD                  REPUBLICAN   False
# 2              MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3     BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                   HALL, GUS         COMMUNIST PARTY USE   False
# ...                       ...                         ...     ...
# 4282            JORGENSEN, JO                 LIBERTARIAN   False
# 4283            PIERCE, BROCK                 INDEPENDENT   False
# 4284                      NaN                         NaN    True
# 4285                OVERVOTES                         NaN   False
# 4286               UNDERVOTES                         NaN   False
#
#       candidatevotes  totalvotes   version  notes party_simplified
# 0             659170     1182850  20210113    NaN         DEMOCRAT
# 1             504070     1182850  20210113    NaN       REPUBLICAN
# 2               9198     1182850  20210113    NaN            OTHER
# 3               6669     1182850  20210113    NaN            OTHER
# 4               1954     1182850  20210113    NaN            OTHER
# ...              ...         ...       ...    ...              ...
# 4282            5768      278503  20210113    NaN      LIBERTARIAN
# 4283            2208      278503  20210113    NaN            OTHER
# 4284            1739      278503  20210113    NaN            OTHER
# 4285             279      278503  20210113    NaN            OTHER
# 4286            1459      278503  20210113    NaN            OTHER
#
# [4287 rows x 15 columns]

# %%
def parties(name_str):
    if (name_str == "REPUBLICAN") or (name_str == "DEMOCRAT"):
        return name_str
    else:
        return "Other"

df_pres["party_detailed"] = df_pres["party_detailed"].apply(parties)
df_pres
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
#                     candidate party_detailed writein  candidatevotes  \
# 0               CARTER, JIMMY       DEMOCRAT   False          659170
# 1                FORD, GERALD     REPUBLICAN   False          504070
# 2              MADDOX, LESTER          Other   False            9198
# 3     BUBAR, BENJAMIN ""BEN""          Other   False            6669
# 4                   HALL, GUS          Other   False            1954
# ...                       ...            ...     ...             ...
# 4282            JORGENSEN, JO          Other   False            5768
# 4283            PIERCE, BROCK          Other   False            2208
# 4284                      NaN          Other    True            1739
# 4285                OVERVOTES          Other   False             279
# 4286               UNDERVOTES          Other   False            1459
#
#       totalvotes   version  notes party_simplified
# 0        1182850  20210113    NaN         DEMOCRAT
# 1        1182850  20210113    NaN       REPUBLICAN
# 2        1182850  20210113    NaN            OTHER
# 3        1182850  20210113    NaN            OTHER
# 4        1182850  20210113    NaN            OTHER
# ...          ...       ...    ...              ...
# 4282      278503  20210113    NaN      LIBERTARIAN
# 4283      278503  20210113    NaN            OTHER
# 4284      278503  20210113    NaN            OTHER
# 4285      278503  20210113    NaN            OTHER
# 4286      278503  20210113    NaN            OTHER
#
# [4287 rows x 15 columns]

# %%
df_pres = df_pres.loc[df_pres["state_fips"] == 6]
df_pres
# Out:
#       year       state state_po  state_fips  state_cen  state_ic  \
# 23    1976  CALIFORNIA       CA           6         93        71
# 24    1976  CALIFORNIA       CA           6         93        71
# 25    1976  CALIFORNIA       CA           6         93        71
# 26    1976  CALIFORNIA       CA           6         93        71
# 27    1976  CALIFORNIA       CA           6         93        71
# ...    ...         ...      ...         ...        ...       ...
# 3779  2020  CALIFORNIA       CA           6         93        71
# 3780  2020  CALIFORNIA       CA           6         93        71
# 3781  2020  CALIFORNIA       CA           6         93        71
# 3782  2020  CALIFORNIA       CA           6         93        71
# 3783  2020  CALIFORNIA       CA           6         93        71
#
#             office                        candidate party_detailed writein  \
# 23    US PRESIDENT                     FORD, GERALD     REPUBLICAN   False
# 24    US PRESIDENT                    CARTER, JIMMY       DEMOCRAT   False
# 25    US PRESIDENT                  MACBRIDE, ROGER          Other   False
# 26    US PRESIDENT                   MADDOX, LESTER          Other   False
# 27    US PRESIDENT                 WRIGHT, MARGARET          Other   False
# ...            ...                              ...            ...     ...
# 3779  US PRESIDENT                   CARROLL, BRIAN          Other    True
# 3780  US PRESIDENT  JANOS, JAMES G. "JESSE VENTURA"          Other    True
# 3781  US PRESIDENT                     MARK CHARLES          Other    True
# 3782  US PRESIDENT                    PIERCE, BROCK          Other    True
# 3783  US PRESIDENT                   JOSEPH KISHORE          Other    True
#
#       candidatevotes  totalvotes   version  notes party_simplified
# 23           3882244     7803770  20210113    NaN       REPUBLICAN
# 24           3742284     7803770  20210113    NaN         DEMOCRAT
# 25             56388     7803770  20210113    NaN            OTHER
# 26             51098     7803770  20210113    NaN            OTHER
# 27             41731     7803770  20210113    NaN            OTHER
# ...              ...         ...       ...    ...              ...
# 3779            2605    17500881  20210113    NaN            OTHER
# 3780             611    17500881  20210113    NaN            OTHER
# 3781             559    17500881  20210113    NaN            OTHER
# 3782             185    17500881  20210113    NaN            OTHER
# 3783             121    17500881  20210113    NaN            OTHER
#
# [85 rows x 15 columns]

# %%
pres_data = df_pres.groupby(['year','party_detailed'])['candidatevotes'].sum()
df_CAL = pres_data.to_frame();
df_CAL = df_CAL.unstack(level='party_detailed')
df_CAL.columns = df_CAL.columns.droplevel()

year = df_CAL.index
df_CAL['year'] = year
df_CAL
# Out:
# party_detailed  DEMOCRAT    Other  REPUBLICAN  year
# year
# 1976             3742284   179242     3882244  1976
# 1980             3082943   977001     4522994  1980
# 1984             3922519   115513     5467009  1984
# 1988             4702233   129915     5054917  1988
# 1992             5121325  2379822     3630574  1992
# 1996             5119835  1071253     3828381  1996
# 2000             5861203   537190     4567429  2000
# 2004             6745485   166042     5509826  2004
# 2008             8274473   275646     5011781  2008
# 2012             7854285   344304     4839958  2012
# 2016             8753788   943997     4483810  2016
# 2020            11110250   384202     6006429  2020

# %%
plt.figure()
plt.plot(df_CAL.year, df_CAL.DEMOCRAT, 'b')
plt.plot(df_CAL.year, df_CAL.REPUBLICAN, 'r')
plt.plot(df_CAL.year, df_CAL.Other, 'g')
plt.xlabel('Year')
plt.ylabel('Number of Votes')
# Out:
# Text(0, 0.5, 'Number of Votes')

# %%
# Other's never win so don't bother with them
df_CAL['winner'] = np.where(df_CAL['DEMOCRAT'] > df_CAL['REPUBLICAN'], 'DEMOCRAT', 'REPUBLICAN')
plt.hist(df_CAL['winner'], bins = 2)
plt.ylabel('Number of Victories')
# Out:
# Text(0, 0.5, 'Number of Victories')
